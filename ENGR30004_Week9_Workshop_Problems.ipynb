# %% [markdown]
# # ENGR30004
#
# ## Week 9 - Sorting

# %% [markdown]
# Today, we will be looking at sorting algorithms: Bubble Sort, Selection Sort and Insertion Sort

# %% [markdown]
# ### Learning Objectives

# %% [markdown]
# - Discussing Bubble Sort
#     - Understand the mechanisms of Bubble Sort.
#     - Understand the limitations of Bubble Sort.
# - Implementing Selection Sort
#     - Understand and Implement the Selection Sort Algorithm.
#     - Understand the advantages of Selection Sort over Bubble Sort.
#     - Understand the limitations of Selection Sort.
#
# - Implementing Insertion Sort
#     - Understand and Implement the Insertion Sort Algorithm.
#     - Understand the advantages of Insertion Sort over Selection Sort and Bubble Sort.
#     - Understand the limitations of Insertion Sort.

# %% [markdown]
# ### Problem 1: Bubble Sort

# %% [markdown]
# <img alt="" src="data:image/gif;base64,...">

# %% [markdown]
# by: Nmnogueira (https://en.wikipedia.org/wiki/User:Nmnogueira)

# %% [markdown]
# Consider the following list:
#
# `8, 4, 9, 2, 7, 2, 5, 6`
#
# Manually run two iterations of Bubble Sort on this list.
#
# - Discuss the time complexity of Bubble Sort.
# - Discuss the space complexity of Bubble Sort.
# - Why is Bubble Sort bad?

# %% [markdown]
# (You may code a bubble sort algorithm in your own time, to better understand the bubble sort mechanisms)

# %% [markdown]
# ### Problem 2: Selection Sort

# %% [markdown]
# <img alt="" src="data:image/gif;base64,...">

# %% [markdown]
# by: Joestape89 (https://en.wikipedia.org/wiki/Selection_sort#/media/File:Selection-Sort-Animation.gif)

# %% [markdown]
# Let us sort the list `8, 4, 9, 2, 7, 2, 5, 6` manually using Selection Sort

# %% [markdown]
# |Sorted Sub-List|Unsorted Sub-List|Least element in the unsorted Sub-List|
# |---|---:|---|
# |[]|[8, 4, 9, 2, 7, 2, 5, 6]|2|
# |[2]|[8, 4, 9, 2, 7, 5, 6]|2|
# |[2, 2]|[8, 4, 9, 7, 5, 6]|4|
# |[2, 2, 4]|[8, 9, 7, 5, 6]|5|
# |[2, 2, 4, 5]|[8, 9, 7, 6]|6|
# |[2, 2, 4, 5, 6]|[8, 9, 7]|7|
# |[2, 2, 4, 5, 6, 7]|[8, 9]|8|
# |[2, 2, 4, 5, 6, 7, 8]|[9]|9|
# |[2, 2, 4, 5, 6, 7, 8, 9]|[]||

# %% [markdown]
# Implement the insertion sort algorithm. Use the following code snippet to get you started.

# %%
def selection_sort(unsorted_list):
    pass

ls = [8, 4, 9, 2, 7, 2, 5, 6]
sorted_ls = selection_sort(ls)

print(sorted_ls)
# Out:
# None

# %% [markdown]
# **Discuss**: how can we improve selection sort further?

# %% [markdown]
# ### Problem 3: Insertion Sort

# %% [markdown]
# <img alt="" src="data:image/gif;base64,...">

# %% [markdown]
# by: Swfung8 (https://en.wikipedia.org/wiki/Insertion_sort#/media/File:Insertion-sort-example-300px.gif)

# %% [markdown]
# Let us sort the list `8, 4, 9, 2, 7, 2, 5, 6` manually using Insertion Sort

# %% [markdown]
# |less than or equal to x| x | greater than x|Unsorted|
# |---|:---:|---:|---|
# |[]|-|[]|[8, 4, 9, 2, 7, 2, 5, 6]|
# |[]|8|[]|[4, 9, 2, 7, 2, 5, 6]|
# |[]|4|[8]|[9, 2, 7, 2, 5, 6]|
# |[4, 8]|9|[]|[2, 7, 2, 5, 6]|
# |[]|2|[4, 8, 9]|[7, 2, 5, 6]|
# |[2, 4]|7|[8, 9]|[2, 5, 6]|
# |[2]|2|[4, 7, 8, 9]|[5, 6]|
# |[2, 2, 4]|5|[7, 8, 9]|[6]|
# |[2, 2, 4, 5]|6|[7, 8, 9]|[]|

# %% [markdown]
# Implement the insertion sort algorithm. Use the following code snippet to get you started.

# %%
def insertion_sort(unsorted_list):
    pass

ls = [8, 4, 9, 2, 7, 2, 5, 6]
sorted_ls = insertion_sort(ls)

print(sorted_ls)
# Out:
# None

# %% [markdown]
# **Discuss**: What is meant when we say that insertion sort is *stable, inplace, and online*?
